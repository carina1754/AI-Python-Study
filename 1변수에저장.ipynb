# %%
1+2
# Out:
# 3

# %%
var1=5

# %%
var1
# Out:
# 5

# %%
var1=10
var1
# Out:
# 10

# %%
var2=20
var2
# Out:
# 20

# %%
var3 = var1 + var2
var3
# Out:
# 30

# %%
print(var1)
# Out:
# 10

# %%
print(var1+var2)
# Out:
# 30

# %%
print(var1,var2)
# Out:
# 10 20

# %%
print("덧셈:",var1+var2)
# Out:
# 덧셈: 30
