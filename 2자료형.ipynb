# %% [markdown]
# ### 2-1 *숫자형*

# %% [markdown]
# int=정수형 ex)-3,-2,-1,0,1,2,3
#  float=실수형 ex)3.14, 0.1, 10.5, 1.23456, 1e-6

# %%
var1=10
type(var1)
# Out:
# int

# %%
var2=3.14
type(var2)
# Out:
# float

# %%
var3=1+2
var4=3+0.14

print(type(var3))
print(type(var4))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ### 2-2 문자열

# %%
str1="Easy"
str1
# Out:
# 'Easy'

# %%
print(type(str1))
# Out:
# <class 'str'>

# %%
str2="파이썬 딥러닝"
str2
# Out:
# '파이썬 딥러닝'

# %%
str3="ver1.0"
print(type(str3))
# Out:
# <class 'str'>

# %%
len(str1)
# Out:
# 4

# %%
len(str3)
# Out:
# 6

# %%
str1[0]
# Out:
# 'E'

# %%
str1[3]
# Out:
# 'y'

# %%
str1[-1]
# Out:
# 'y'

# %%
str1[0:3]
# Out:
# 'Eas'

# %%
str1[-3:-1]
# Out:
# 'as'

# %%
str1[-3:-2]
# Out:
# 'a'

# %%
str1[-3:]
# Out:
# 'asy'

# %%
str4="%s 파이썬 딥러닝"%str1
str4
# Out:
# 'Easy 파이썬 딥러닝'

# %%
str5="파이썬 %s 딥러닝"%str1
str5
# Out:
# '파이썬 Easy 딥러닝'

# %% [markdown]
# ### 2-3 리스트

# %%
list1=[1,2,3,4,5]
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
type(list1)
# Out:
# list

# %%
list2=[10]
print(list2)
print(type(list2))
# Out:
# [10]
# <class 'list'>

# %%
list3=list()
print(list3)
# Out:
# []

# %%
list4=[]
list4
# Out:
# []

# %%
list_of_list=[list1,list2,list3]
list_of_list
# Out:
# [[1, 2, 3, 4, 5], [10], []]

# %%
type(list_of_list)
# Out:
# list

# %%
list_of_list[0]
# Out:
# [1, 2, 3, 4, 5]

# %%
list_of_list[0][1]
# Out:
# 2

# %%
list_of_list[-1]
# Out:
# []

# %%
list_of_list[-3]
# Out:
# [1, 2, 3, 4, 5]

# %%
list_of_list[0:2]
# Out:
# [[1, 2, 3, 4, 5], [10]]

# %%
list1.append(100)
list1
# Out:
# [1, 2, 3, 4, 5, 100]

# %%
list3.append(7)
list3.append(8)
list3.append(9)
list3
# Out:
# [7, 8, 9]

# %% [markdown]
# ###2-4 투플

# %% [markdown]
# **투플(tuple)**은 리스트 자료구조와 형태가 비슷하다. 여러 원소를 순서대로 저장할 수 있고 각 원소를 쉼표(,)로 구분해 준다. 단 리스트는 []안에 원소를 입력하지만, 투플은 ()안에 원소를 입력한다.

# %% [markdown]
# 가장 큰 차이점은 투플은 리스트와 다르게 원소를 추가하거나 삭제할 수 없다는 점이다. **즉, 프로그램이 실행되는 동안 데이터의 순서와 값이 바뀌지 않아야 하는 경우에 사용한다.**

# %%
tuple1=(1,2)
tuple1
# Out:
# (1, 2)

# %%
type(tuple1)
# Out:
# tuple

# %%
tuple2=("a","b",100)
tuple2
# Out:
# ('a', 'b', 100)

# %%
tuple3=tuple()
tuple4=()
tuple3
tuple4
# Out:
# ()

# %%
tuple3=tuple()
tuple4=()
print(tuple3)
print(tuple4)
# Out:
# ()
# ()

# %%
tuple2[0]
# Out:
# 'a'

# %%
tuple2[1:]
# Out:
# ('b', 100)

# %% [markdown]
# ###2-5 딕셔너리

# %% [markdown]
# 여러 개의 원소를 담는 자료형 중에서 딕셔너리(dictionary)는 형태가 독특하다."키(key):값(value)"쌍을 원소로 갖는데, 중괄호 {} 안에 원소(키:값)를 쉼표(,)로 구분하여 입력한다.

# %%
dict1={'name':'Jay',"age":20}
dict1
# Out:
# {'age': 20, 'name': 'Jay'}

# %%
type(dict1)
# Out:
# dict

# %%
dict1['name']
# Out:
# 'Jay'

# %%
dict1["age"]
# Out:
# 20

# %%
dict1['graede']=[3.0, 4.0, 3.5, 4.2]
dict1
# Out:
# {'age': 20, 'graede': [3.0, 4.0, 3.5, 4.2], 'name': 'Jay'}

# %%
dict1.keys()
# Out:
# dict_keys(['name', 'age', 'graede'])

# %%
dict1.values()
# Out:
# dict_values(['Jay', 20, [3.0, 4.0, 3.5, 4.2]])

# %%
print(dict1)
# Out:
# {'name': 'Jay', 'age': 20, 'graede': [3.0, 4.0, 3.5, 4.2]}

# %%
dict1.items()
# Out:
# dict_items([('name', 'Jay'), ('age', 20), ('graede', [3.0, 4.0, 3.5, 4.2])])
